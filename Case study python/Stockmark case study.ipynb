# %%
 # %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\dell\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (4.1.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.15 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\dell\anaconda3\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\dell\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.4.22)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (14.2.0)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# load real stock data
# name 

stock = yf.download("RELIANCE.NS",start ="2025-01-01",end="2026-01-01")
stock.head()
 # stock.to_csv("RELIANCE.csv") # saving the data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-01-01  1210.793579  1215.800389  1201.226179  1204.448352     5892590
# 2025-01-02  1231.167725  1233.794938  1209.554328  1210.793626    15486276
# 2025-01-03  1240.437744  1251.244443  1224.921714  1233.249818    15521102
# 2025-01-06  1207.571411  1251.194681  1204.597097  1243.213557    14816766
# 2025-01-07  1230.225708  1233.844481  1210.793549  1211.537128    10070505

# %%
plt.figure()
plt.plot(stock['Close'])
plt.title("RELIANCE.NS")
plt.xlabel("data")
plt.ylabel("price(inr)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(stock['Open'])
plt.title("RELIANCE.NS")
plt.xlabel("data")
plt.ylabel("price(inr)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
stock['MA50'] = stock['Close'].rolling(window=50).mean()
stock['MA70'] = stock['Close'].rolling(window=70).mean()

# %%
plt.plot(stock['Close'],label='Close Price')
plt.plot(stock['MA50'],label='50 Days MA')
plt.plot(stock['MA50'],label='100 Days MA')
plt.title("RELIANCE.NS")
plt.xlabel("data")
plt.ylabel("price(inr)")
plt.legend()
plt.show()

# %%
# bar chart volume

# %%
 stock.columns
# Out:
# MultiIndex([( 'Close', 'RELIANCE.NS'),
#             (  'High', 'RELIANCE.NS'),
#             (   'Low', 'RELIANCE.NS'),
#             (  'Open', 'RELIANCE.NS'),
#             ('Volume', 'RELIANCE.NS'),
#             (  'MA50',            ''),
#             (  'MA70',            '')],
#            names=['Price', 'Ticker'])

# %%
plt.bar(stock.index,stock['Volume']["RELIANCE.NS"])
plt.title("RELIANCE.NS")
plt.xlabel("data")
plt.ylabel("price(inr)")
plt.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19580\3712707449.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# candle stick chart

# %%
# %pip install  mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\dell\anaconda3\lib\site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (from mplfinance) (3.10.6)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (from mplfinance) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas->mplfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\lib\site-packages (from pandas->mplfinance) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mplfinance as mpf
stock.columns = stock.columns.droplevel(1)

# convert to float
stock = stock.astype(float)

# plot
mpf.plot(stock,type='candle',volume=True,title='Reliance stock')

# %%
stocks = yf.download(["RELIANCE.NS","TCS.NS"],start="2023-01-01",end="2024-01-01")
plt.plot(stocks['Close']['RELIANCE.NS'],label="Reliance")
plt.plot(stocks['Close']['TCS.NS'],label="TCS")
plt.legend()
plt.title("stocks")
plt.show()
# Out:
# [*********************100%***********************]  1 of 2 completed

# %%
# daily return 
stock ['Daily Return'] = stock['Close'].pct_change()
plt.plot(stock['Daily Return'])
plt.title("Daily Returns")
plt.show()


# histogram risk anlysis
plt.hist(stock['Daily Return'].dropna(),bins=50)
plt.title("Return Distribustion")
plt.show()
